# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3b342c5f7916> in <module>()
# ----> 1 s = pd.Series(data, index=index)
#
# NameError: name 'data' is not defined

# %%
s = pd.Series(np.random.rand(5), index = ["a","b","c","d","e"])
s
# Out:
# a    0.223220
# b    0.212311
# c    0.163990
# d    0.620250
# e    0.083438
# dtype: float64

# %%
d = {"a":0, "b":1, "c":2, "d":3}
pd.Series(d)
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64
